# %%
from kafka import KafkaConsumer
import json
from multiprocessing import Process
import logging
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
plt.rcParams['animation.html'] = 'jshtml'

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
def get_current_offsets(consumer):
    current_offsets = {}

    # Obtém a lista de partições atribuídas ao consumidor
    partitions = consumer.assignment()

    for partition in partitions:
        # Obtém o offset atual para cada partição
        offset = consumer.position(partition)
        current_offsets[partition] = offset

    return current_offsets

# %%
def topic_consumer():
    
    consumer = KafkaConsumer('sales-msg', bootstrap_servers=['localhost:19092','localhost:29092','localhost:39092'],
    api_version=(0,10,2),
    group_id='jupyter-consumers',
    enable_auto_commit=False)

    flag=0
    
    try:
        for message in consumer:
            message = message.value.decode('utf-8')
            if flag == 0:
                df_sales=pd.read_json(message)
                flag=1
            else:
                df_sales=pd.concat([df_sales,pd.read_json(message)])
                
                print('Mensagem concatenada. Offset atual e: {}'.format(get_current_offsets(consumer)))
            consumer.commit()

            
    except Exception as e:
        logging.error(f"Error consuming message: {str(e)}")

# %%
def topic_consumer():
    consumer = KafkaConsumer('sales-msg', bootstrap_servers=['localhost:19092','localhost:29092','localhost:39092'],
    api_version=(0,10,2),
    group_id='jupyter-consumers',
    enable_auto_commit=False)
    
    try:
        while True:
            message = consumer.poll(timeout_ms=3000)
            
            if message:
                for _, msgs in message.items():
                    for msg in msgs:
                        if flag == 0:
                            df_sales=pd.read_json(msg.value)
                            flag=1
                        else:
                            df_sales=pd.concat([df_sales,pd.read_json(msg.value)])
                        
                        consumer.commit()
            else:
                print("Mensagens finalizaram")
                break
    except Exception as e:
        # Registra o erro
        logging.error(f"Error consuming message from topic '{topic}': {str(e)}")
        # Realiza tratamento de erros, como reprocessar a mensagem ou enviar para uma fila de erros
    
    # Retorna as mensagens do tópico como uma lista
    return messages

# %%
def mltpcssng_consumer():
    logging.basicConfig(filename='consumer.log', level=logging.ERROR)
    
    n_consumer=3
    readden=[]
    
    for _ in range(n_consumer):
        p = Process(target=topic_consumer)
        p.daemon = True
        readden.append(p)
    
    for p in readden:
        p.start()
    
    for p in readden:
        p.join()

# %% [markdown]
# mltpcssng_consumer()
